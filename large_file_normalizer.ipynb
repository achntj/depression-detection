# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('datasets_scraped/large-dataset.csv', index_col=None)
df.columns = ['sentiment', 'id', 'description', 'Query', 'username', 'text']
df = df.drop(['Query', 'id'], 1)
df
# Out:
#          sentiment                   description         username  \
# 0                0  Mon Apr 06 22:19:49 PDT 2009    scotthamilton
# 1                0  Mon Apr 06 22:19:53 PDT 2009         mattycus
# 2                0  Mon Apr 06 22:19:57 PDT 2009          ElleCTF
# 3                0  Mon Apr 06 22:19:57 PDT 2009           Karoli
# 4                0  Mon Apr 06 22:20:00 PDT 2009         joy_wolf
# ...            ...                           ...              ...
# 1599994          4  Tue Jun 16 08:40:49 PDT 2009  AmandaMarie1028
# 1599995          4  Tue Jun 16 08:40:49 PDT 2009      TheWDBoards
# 1599996          4  Tue Jun 16 08:40:49 PDT 2009           bpbabe
# 1599997          4  Tue Jun 16 08:40:49 PDT 2009     tinydiamondz
# 1599998          4  Tue Jun 16 08:40:50 PDT 2009   RyanTrevMorris
#
#                                                       text
# 0        is upset that he can't update his Facebook by ...
# ...

# %%
cols = df.columns.tolist()
cols = ['username', 'sentiment', 'text', 'description']
df = df[cols]
df
# Out:
#                 username  sentiment  \
# 0          scotthamilton          0
# 1               mattycus          0
# 2                ElleCTF          0
# 3                 Karoli          0
# 4               joy_wolf          0
# ...                  ...        ...
# 1599994  AmandaMarie1028          4
# 1599995      TheWDBoards          4
# 1599996           bpbabe          4
# 1599997     tinydiamondz          4
# 1599998   RyanTrevMorris          4
#
#                                                       text  \
# 0        is upset that he can't update his Facebook by ...
# 1        @Kenichan I dived many times for the ball. Man...
# 2          my whole body feels itchy and like its on fire
# 3        @nationwideclass no, it's not behaving at all....
# 4                            @Kwesidei not the whole crew
# ...                                                    ...
# 1599994  Just woke up. Having no school is the best fee...
# ...

# %%
# from textblob import TextBlob
# sentiment = []

# for sentence in df['text']: 
#     sentiment.append(TextBlob(sentence).sentiment.polarity*10)

# df['sentiment'] = sentiment
# df

# %%
df.to_csv('./datasets_scraped/kaggle-dataset')
